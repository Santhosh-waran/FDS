# %%
import pandas as pd

# Create the DataFrame
data = {
    's.no': [1, 2, 3, 4, 5, 6, 7],
    'rollno': [100, 101, 102, 103, 104, 105, 106],
    'name': ['a', 'b', 'c', 'd', 'e', 'f', 'g'],
    'sub1': [91, 95, 92, 91, 89, 87, 89],
    'sub2': [89, 95, 94, 92, 81, 94, 93],
    'sub3': [87, 89, 87, 91, 92, 94, 92]
}

df = pd.DataFrame(data)

file_path = 'student_data.xlsx'
df.to_excel(file_path, index=False)

print(f"Excel file created at: {file_path}")
# Out:
# Excel file created at: student_data.xlsx

# %%
import pandas as pd  
df= pd.read_excel("student_data.xlsx")  
print(df)
# Out:
#    s.no  rollno name  sub1  sub2  sub3
# 0     1     100    a    91    89    87
# 1     2     101    b    95    95    89
# 2     3     102    c    92    94    87
# 3     4     103    d    91    92    91
# 4     5     104    e    89    81    92
# 5     6     105    f    87    94    94
# 6     7     106    g    89    93    92

# %%
import pandas as pd 
# df =pd.read_excel("D:\mark.xls") 
df['total']=df['sub1']+df['sub2']+df['sub3']  
df.to_excel("mark.xlsx") 
print(df)
# Out:
#    s.no  rollno name  sub1  sub2  sub3  total
# 0     1     100    a    91    89    87    267
# 1     2     101    b    95    95    89    279
# 2     3     102    c    92    94    87    273
# 3     4     103    d    91    92    91    274
# 4     5     104    e    89    81    92    262
# 5     6     105    f    87    94    94    275
# 6     7     106    g    89    93    92    274

# %%
import pandas as  pd
df=pd.read_excel("mark.xlsx")  
df.to_csv("mark_1.csv") 
df=pd.DataFrame(pd.read_csv("mark_1.csv")) 
print(df)
# Out:
#    Unnamed: 0.1  Unnamed: 0  s.no  rollno name  sub1  sub2  sub3  total
# 0             0           0     1     100    a    91    89    87    267
# 1             1           1     2     101    b    95    95    89    279
# 2             2           2     3     102    c    92    94    87    273
# 3             3           3     4     103    d    91    92    91    274
# 4             4           4     5     104    e    89    81    92    262
# 5             5           5     6     105    f    87    94    94    275
# 6             6           6     7     106    g    89    93    92    274

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('iris')
df.to_csv("iris.csv")

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(df.isnull().sum()) 
df
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data=df.drop_duplicates(subset="species",    ignore_index= True)
print(data)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.1          3.5           1.4          0.2      setosa
# 1           7.0          3.2           4.7          1.4  versicolor
# 2           6.3          3.3           6.0          2.5   virginica

# %%
df = pd.read_csv("iris.csv")
print(df.value_counts("species"))
df
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        species
# 0       setosa
# ...

# %%
 
sum_data = df["sepal_length"].sum() 
mean_data=df["sepal_length"].mean() 
median_data=df["sepal_length"].median()  
print("Sum:",sum_data,"\nMean:",mean_data,"\nMedian:",median_data)
# Out:
# Sum: 876.5
# Mean: 5.843333333333334
# Median: 5.8

# %%
import pandas as pd 
import matplotlib.pyplot as plt  
# df=pd.read_csv("D:\iris.csv") 
plt.scatter(df["sepal_width"],df["sepal_length"])
plt.xlabel("sepalwidth") 
plt.ylabel("sepal length") 
plt.show()

# %%
df.plot(kind="scatter",x="petal_length",y="petal_width",color="red",s=70) 
plt.show()

# %%
sns.set(style="ticks",color_codes=True) 
# df=pd.read_csv('D:\iris.csv') 
g=sns.pairplot(df,hue='species') 
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...
